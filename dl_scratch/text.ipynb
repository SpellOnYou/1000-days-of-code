# %%
# !git clone https://github.com/fastai/course-v3
# Out:
# Cloning into 'course-v3'...
# remote: Enumerating objects: 5893, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 5893 (delta 0), reused 2 (delta 0), pack-reused 5890
# Receiving objects: 100% (5893/5893), 263.03 MiB | 34.22 MiB/s, done.
# Resolving deltas: 100% (3249/3249), done.

# %%
# %cd /content/course-v3/nbs/dl2
# Out:
# /content/course-v3/nbs/dl2

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# !apt-get install apex
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# E: Unable to locate package apex

# %% [markdown]
# - resource
#     - https://stackoverflow.com/questions/57284345/how-to-install-nvidia-apex-on-google-colab
#     - https://colab.research.google.com/drive/1SDc9caTWxgZ56vqP6zj2Pz83qXxbXpWc
#     - https://github.com/NVIDIA/apex#quick-start

# %%
# !git clone https://github.com/NVIDIA/apex
# %cd apex
# !pip install -v --disable-pip-version-check --no-cache-dir --global-option="--cpp_ext" --global-option="--cuda_ext" ./
# Out:
# Cloning into 'apex'...
# remote: Enumerating objects: 8639, done.
# remote: Counting objects: 100% (726/726), done.
# remote: Compressing objects: 100% (450/450), done.
# remote: Total 8639 (delta 430), reused 473 (delta 264), pack-reused 7913
# Receiving objects: 100% (8639/8639), 14.46 MiB | 16.62 MiB/s, done.
# Resolving deltas: 100% (5831/5831), done.
# /content/course-v3/nbs/dl2/apex
# /usr/local/lib/python3.7/dist-packages/pip/_internal/commands/install.py:232: UserWarning: Disabling all use of wheels due to the use of --build-option / --global-option / --install-option.
#   cmdoptions.check_install_build_global(options)
# Using pip 21.1.3 from /usr/local/lib/python3.7/dist-packages/pip (python 3.7)
# Value for scheme.platlib does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/lib/python3.7/dist-packages
# sysconfig: /usr/lib/python3.7/site-packages
# ...

# %%
from exp.nb_11a import *

# %%
import os; os.cpu_count()
# Out:
# 4

# %%
datasets.untar
